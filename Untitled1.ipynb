# %% [markdown]
# <a href="https://colab.research.google.com/github/Nemalipurilikhitha7/ot12_sentiment-analysis/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
review1="The movie was so fentastic ,I loved the acting and plot"
review2="The movie was so boring ,I hated the acting and plot"

# %%
def preprocess_text(text):
  tokens=word_tokenize(text)
  tokens=[word.lower() for word in tokens]
  stop_words=set(stopwords.words("english"))
  tokens=[word for word in tokens if word not in stop_words]
  lemmatizer=WordNetLemmatizer()
  tokens=[lemmatizer.lemmatize(word) for word in tokens]
  return " ".join(tokens)

# %%
a=preprocess_text(review1)
b=preprocess_text(review2)

# %%
vectorizer=TfidfVectorizer()
vectors=vectorizer.fit_transform([a,b])
vectors.toarray()
# Out:
# array([[0.37930349, 0.        , 0.53309782, 0.        , 0.53309782,
#         0.37930349, 0.37930349],
#        [0.37930349, 0.53309782, 0.        , 0.53309782, 0.        ,
#         0.37930349, 0.37930349]])

# %%
cosine_sim=cosine_similarity(vectors[0],vectors[1])[0][0]
print(round(cosine_sim,3))
# Out:
# 0.432

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/content/train.csv")
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
df.shape
# Out:
# (27481, 4)

# %%
df['text1_clean']=df['text'].astype(str).apply(preprocess_text)
df['text2_clean']=df['selected_text'].astype(str).apply(preprocess_text)

# %%
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                                   text1_clean          text2_clean
# 0                         ` responded , going  ` responded , going
# 1               sooo sad miss san diego ! ! !             sooo sad
# 2                            bos bullying ...             bullying
# ...

# %%
vectorizer=TfidfVectorizer()
tfidf_matrix1=vectorizer.fit_transform(df['text1_clean'])
tfidf_matrix2=vectorizer.transform(df['text2_clean'])

# %%
cosine_sim=cosine_similarity(tfidf_matrix1,tfidf_matrix2)
df['cosine_sim']=cosine_sim.diagonal()

# %%
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                                   text1_clean          text2_clean  cosine_sim
# 0                         ` responded , going  ` responded , going    1.000000
# 1               sooo sad miss san diego ! ! !             sooo sad    0.535921
# ...

# %%
def jaccab_similarity(text1,text2):
  tokens1=set(text1.split())
  tokens2=set(text2.split())
  intersection=tokens1.intersection(tokens2)
  union=tokens1.union(tokens2)
  if len(union)==0:
    return 0
  else:
    return len(intersection)/len(union)

# %%
df['jaccab_sim']=df.apply(lambda x:jaccab_similarity(x['text1_clean'],x['text2_clean']),axis=1)

# %%
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                                   text1_clean          text2_clean  \
# 0                         ` responded , going  ` responded , going
# 1               sooo sad miss san diego ! ! !             sooo sad
# 2                            bos bullying ...             bullying
# ...
